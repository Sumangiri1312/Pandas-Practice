# %%
import pandas as pd

# %%
marks=[64,74,75,77]
subjects=["math", "english", "science", "physics"]

# %%
pd.Series(marks)
# Out:
# 0    64
# 1    74
# 2    75
# 3    77
# dtype: int64

# %%
a=pd.Series(marks , index=subjects,  name="suman giri")
print(a)
# Out:
# math       64
# english    74
# science    75
# physics    77
# Name: suman giri, dtype: int64

# %% [markdown]
# **SERIES ATTRIBUTES**

# %%
a.size
# Out:
# 4

# %%
a.is_unique
# Out:
# True

# %%
print(a.dtype)
print(a.values)
print(a.index)
print(a.name)
# Out:
# int64
# [64 74 75 77]
# Index(['math', 'english', 'science', 'physics'], dtype='object')
# suman giri

# %%
import pandas as pd

# %%
student=pd.read_csv('student.csv', index_col='roll_no').squeeze()
print(student)
type(student)
# Out:
# roll_no
# 1       suman
# 2      bikash
# 3         ram
# 4      shikha
# 5       akash
# 6       sagar
# 7       samir
# 8     shishir
# 9       shita
# 10       hari
# Name: name, dtype: object
# pandas.core.series.Series

# %%
student[1:3]
# Out:
# roll_no
# 2    bikash
# 3       ram
# Name: name, dtype: object

# %%
std=pd.read_csv('std.csv',index_col='name')
print(std)
# Out:
#         roll  number
# name
# suman      1  214124
# bikaf      2    5235
# dgjsgg     3     124
# wqrwt      4    5124
# shsdte     5    1351
# afggg      6     512
# gsdgad     7    5125
# gew        8    1244
# svgggg     9  124124
# afff      10   44124

# %%
student.describe()
# Out:
# count        10
# unique       10
# top       suman
# freq          1
# Name: name, dtype: object

# %%
std.describe()
# Out:
#            roll         number
# count  10.00000      10.000000
# mean    5.50000   40108.700000
# std     3.02765   72417.984609
# min     1.00000     124.000000
# 25%     3.25000    1270.750000
# 50%     5.50000    5124.500000
# 75%     7.75000   34401.750000
# max    10.00000  214124.000000

# %%
std.plot()
# Out:
# <Axes: xlabel='name'>

# %%
std.plot(kind='bar')
# Out:
# <Axes: xlabel='name'>

# %%
std
# Out:
#         roll  number
# name
# suman      1  214124
# bikaf      2    5235
# dgjsgg     3     124
# wqrwt      4    5124
# shsdte     5    1351
# afggg      6     512
# gsdgad     7    5125
# gew        8    1244
# svgggg     9  124124
# afff      10   44124

# %%
import pandas as pd

# %%
new=pd.Series([10,20,19,39,40,pd.NA,22,45,77,43, pd.NA,65])
new
# Out:
# 0       10
# 1       20
# 2       19
# 3       39
# 4       40
# 5     <NA>
# 6       22
# 7       45
# 8       77
# 9       43
# 10    <NA>
# 11      65
# dtype: object

# %%
new[new.isin([10,65])]
# Out:
# 0     10
# 11    65
# dtype: object

# %%
new.duplicated().sum()
# Out:
# np.int64(1)

# %%
new[new.between(10,50)]
# Out:
# 0    10
# 1    20
# 2    19
# 3    39
# 4    40
# 6    22
# 7    45
# 9    43
# dtype: object

# %%
new.fillna(0)
# Out:
# C:\Users\LOQ\AppData\Local\Temp\ipykernel_10088\3277644473.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   new.fillna(0)
# 0     10
# 1     20
# 2     19
# 3     39
# 4     40
# 5      0
# 6     22
# 7     45
# 8     77
# 9     43
# 10     0
# 11    65
# dtype: int64
