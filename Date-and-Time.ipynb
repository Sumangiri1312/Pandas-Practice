# %%
import pandas as pd
import numpy as np

# %%
# creating a timestamp
pd.Timestamp('2026/8/15')
# Out:
# Timestamp('2026-08-15 00:00:00')

# %%
pd.Timestamp('15th August 2026')
# Out:
# Timestamp('2026-08-15 00:00:00')

# %%
date=pd.Timestamp('2026-8-15 5:38PM')
date
# Out:
# Timestamp('2026-08-15 17:38:00')

# %%
date.month
date.year
date.minute
# Out:
# 38

# %%
date + pd.to_timedelta(np.arange(12), unit='D')
# Out:
# DatetimeIndex(['2026-08-15 17:38:00', '2026-08-16 17:38:00',
#                '2026-08-17 17:38:00', '2026-08-18 17:38:00',
#                '2026-08-19 17:38:00', '2026-08-20 17:38:00',
#                '2026-08-21 17:38:00', '2026-08-22 17:38:00',
#                '2026-08-23 17:38:00', '2026-08-24 17:38:00',
#                '2026-08-25 17:38:00', '2026-08-26 17:38:00'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# # DatetimeIndex Object
# A collection of pandas timestamp

# %%
pd.DatetimeIndex(['2026-08-15', '2025-08-15', '2024-08-15'])
# Out:
# DatetimeIndex(['2026-08-15', '2025-08-15', '2024-08-15'], dtype='datetime64[ns]', freq=None)

# %%
dt_index = pd.DatetimeIndex([pd.Timestamp(2023,1,1),pd.Timestamp(2022,1,1),pd.Timestamp(2021,1,1)])
dt_index
# Out:
# DatetimeIndex(['2023-01-01', '2022-01-01', '2021-01-01'], dtype='datetime64[ns]', freq=None)

# %%
pd.Series([1,2,3], index=dt_index)
# Out:
# 2023-01-01    1
# 2022-01-01    2
# 2021-01-01    3
# dtype: int64

# %%
# generate daily dates in a given range
pd.date_range(start='2026/8/15',end='2026/9/10',freq='D')
# Out:
# DatetimeIndex(['2026-08-15', '2026-08-16', '2026-08-17', '2026-08-18',
#                '2026-08-19', '2026-08-20', '2026-08-21', '2026-08-22',
#                '2026-08-23', '2026-08-24', '2026-08-25', '2026-08-26',
#                '2026-08-27', '2026-08-28', '2026-08-29', '2026-08-30',
#                '2026-08-31', '2026-09-01', '2026-09-02', '2026-09-03',
#                '2026-09-04', '2026-09-05', '2026-09-06', '2026-09-07',
#                '2026-09-08', '2026-09-09', '2026-09-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2026/8/15', periods=25, freq='ME')
# Out:
# DatetimeIndex(['2026-08-31', '2026-09-30', '2026-10-31', '2026-11-30',
#                '2026-12-31', '2027-01-31', '2027-02-28', '2027-03-31',
#                '2027-04-30', '2027-05-31', '2027-06-30', '2027-07-31',
#                '2027-08-31', '2027-09-30', '2027-10-31', '2027-11-30',
#                '2027-12-31', '2028-01-31', '2028-02-29', '2028-03-31',
#                '2028-04-30', '2028-05-31', '2028-06-30', '2028-07-31',
#                '2028-08-31'],
#               dtype='datetime64[ns]', freq='ME')

# %% [markdown]
# # to_datetime function
# converts an existing objects to pandas timestamp/datetimeindex object

# %%
s= pd.Series(['2026-8-15', '2025-8-15', '2024-8-15'])
s
# Out:
# 0    2026-8-15
# 1    2025-8-15
# 2    2024-8-15
# dtype: object

# %%
pd.to_datetime(s)
# Out:
# 0   2026-08-15
# 1   2025-08-15
# 2   2024-08-15
# dtype: datetime64[ns]

# %%
pd.to_datetime(s).dt.year
# Out:
# 0    2026
# 1    2025
# 2    2024
# dtype: int32

# %%
# with errors
s= pd.Series(['2026-8-15', '2025-8-15', '2024-843-15'])
pd.to_datetime(s,errors='coerce').dt.day_name()
# Out:
# 0    Saturday
# 1      Friday
# 2         NaN
# dtype: object

# %%
df = pd.read_csv('expense_data.csv')
df
# Out:
#                  Date               Account        Category  Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food          NaN
# 1      3/2/2022 10:11  CUB - online payment           Other          NaN
# 2      3/1/2022 19:50  CUB - online payment            Food          NaN
# 3      3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4      3/1/2022 18:22  CUB - online payment            Food          NaN
# ..                ...                   ...             ...          ...
# 272  11/22/2021 14:16  CUB - online payment            Food          NaN
# 273  11/22/2021 14:16  CUB - online payment            Food          NaN
# 274  11/21/2021 17:07  CUB - online payment  Transportation          NaN
# 275  11/21/2021 15:50  CUB - online payment            Food          NaN
# 276  11/21/2021 13:30  CUB - online payment           Other          NaN
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# ...

# %%
df['Date']= pd.to_datetime(df['Date'])
df
# Out:
#                    Date               Account        Category  Subcategory  \
# 0   2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1   2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2   2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3   2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4   2022-03-01 18:22:00  CUB - online payment            Food          NaN
# ..                  ...                   ...             ...          ...
# 272 2021-11-22 14:16:00  CUB - online payment            Food          NaN
# 273 2021-11-22 14:16:00  CUB - online payment            Food          NaN
# 274 2021-11-21 17:07:00  CUB - online payment  Transportation          NaN
# 275 2021-11-21 15:50:00  CUB - online payment            Food          NaN
# 276 2021-11-21 13:30:00  CUB - online payment           Other          NaN
#
# ...

# %%
df['Date'].dt.month_name()
# Out:
# 0         March
# 1         March
# 2         March
# 3         March
# 4         March
#          ...
# 272    November
# 273    November
# 274    November
# 275    November
# 276    November
# Name: Date, Length: 277, dtype: object

# %%
# plot graph
import matplotlib.pyplot as plt
plt.plot(df['Date'],df['INR'])

# %%
# day name wise bar chart/month wise bar chart
df['day_name']=df['Date'].dt.day_name()
df.head()
# Out:
#                  Date               Account        Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2 2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3 2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4 2022-03-01 18:22:00  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1  \
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0
#
#     day_name
# 0  Wednesday
# 1  Wednesday
# 2    Tuesday
# ...

# %%
df.groupby('day_name')['INR'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='day_name'>
